# %%
import pandas as pd
import numpy as np
pd.set_option('max_columns', 120)
pd.set_option('max_colwidth', 5000)


import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)

# %%
xls_2017 = pd.read_excel('2017.xlsx')

# %%
xls_2017.loc[xls_2017.YEAR==0,'YEAR']=2004
xls_2017.loc[xls_2017.YEAR==1,'YEAR']=2005
xls_2017.loc[xls_2017.YEAR==2,'YEAR']=2006
xls_2017.loc[xls_2017.YEAR==3,'YEAR']=2007
xls_2017.loc[xls_2017.YEAR==4,'YEAR']=2008
xls_2017.loc[xls_2017.YEAR==5,'YEAR']=2009
xls_2017.loc[xls_2017.YEAR==6,'YEAR']=2010
xls_2017.loc[xls_2017.YEAR==7,'YEAR']=2011
xls_2017.loc[xls_2017.YEAR==8,'YEAR']=2012
xls_2017.loc[xls_2017.YEAR==9,'YEAR']=2013
xls_2017.loc[xls_2017.YEAR==10,'YEAR']=2014
xls_2017.loc[xls_2017.YEAR==11,'YEAR']=2015
xls_2017.loc[xls_2017.YEAR==12,'YEAR']=2016
xls_2017.loc[xls_2017.YEAR==13,'YEAR']=2017
xls_2017.loc[xls_2017.YEAR==14,'YEAR']='Latest'

# %%
xls_2017.drop(['alternative name','story', '1st source link', '2nd source link', '3rd source', 'source name', 'UNUSED', 'Exclude'],axis=1)
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
xls_2017.drop(['UNUSED', 'UNUSED.1', 'Exclude'],axis=1)
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
xls_2017.drop(xls_2017.columns[[11,12,13,14,15]], axis=1)
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
xls_2017.drop(xls_2017.columns[[11,12,13]], axis=1, inplace= True)

# %%
writer = pd.ExcelWriter('xls_2017_clean.xlsx', engine='xlsxwriter')
xls_2017.to_excel(writer, sheet_name='Sheet1')

# %%
# %save xls_2017[2017_clean]
# Out:
# '' was not found in history, as a file, url, nor in the user namespace.

# %%
xls_2017
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
new_2017 = xls_2017.drop(xls_2017.columns[[11,12,13, 14]], axis=1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-77a6c511b9ca> in <module>()
# ----> 1 new_2017 = xls_2017.drop(xls_2017.columns[[11,12,13, 14]], axis=1, inplace= True)
#
# C:\Users\ameyn\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    1648
#    1649         key = _values_from_object(key)
# -> 1650         result = getitem(key)
#    1651         if not is_scalar(result):
#    1652             return promote(result)
#
# IndexError: index 11 is out of bounds for axis 0 with size 11

# %%
new_2017

# %%
xls_2017
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
new1_2017 = xls_2017.drop(xls_2017.columns[[10]], axis=1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-2841e3d6e725> in <module>()
# ----> 1 new1_2017 = xls_2017.drop(xls_2017.columns[[10]], axis=1, inplace= True)
#
# C:\Users\ameyn\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    1648
#    1649         key = _values_from_object(key)
# -> 1650         result = getitem(key)
#    1651         if not is_scalar(result):
#    1652             return promote(result)
#
# IndexError: index 10 is out of bounds for axis 0 with size 10

# %%
new1_2017=xls_2017

# %%
new1_2017
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
new1_2017.to_excel("2017_clean.xlsx")

# %%
new1_2017.iloc[1:]
# Out:
#                                              Entity  \
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# 17                         Driving Standards Agency
# ...

# %%
new1_2017.loc[(new1_2017['DATA SENSITIVITY']==1),'DATA SENSITIVITY']='Just Email Addresses/Online Information'

# %%
new1_2017
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
new2_2017=new1_2017

# %%
new2_2017
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
new2_2017.iloc[1:]
# Out:
#                                              Entity  \
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# 17                         Driving Standards Agency
# ...

# %%
new2_2017
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
new2_2017.rename(columns={'alternative name':'Alternative Name','story':'Story','YEAR':'Year','records lost':'Records Lost','ORGANISATION':'Organization','METHOD OF LEAK':'Method of Leak','NO OF RECORDS STOLEN':'Nbr of Records Stolen','DATA SENSITIVITY':'Data Sensitivity','1st source link':'Link1','2nd source link':'Link2','3rd source':'Link3','source name':'Source Name'})
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
new2_2017
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
new3_2017=new2_2017

# %%
new3_2017
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
writer = pd.ExcelWriter('2017_using writer.xlsx', engine='xlsxwriter')
new3_2017.to_excel(writer, sheet_name='Sheet1')
workbook  = writer.book
worksheet = writer.sheets['Sheet1']

# Add some cell formats.
format1 = workbook.add_format({'num_format': '#,##0.00'})

# %%
writer.save()

# %%
new3_2017['Records Lost'] = new3_2017.apply(lambda x: "{:,}".format(x['Records Lost']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ameyn\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2433             try:
# -> 2434                 return libts.get_value_box(s, key)
#    2435             except IndexError:
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.get_value_box (pandas\_libs\tslib.c:18843)()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.get_value_box (pandas\_libs\tslib.c:18477)()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-e5899ec218ed> in <module>()
# ----> 1 new3_2017['Records Lost'] = new3_2017.apply(lambda x: "{:,}".format(x['Records Lost']), axis=1)
#
# ...

# %%
new4_2017=new3_2017.iloc[1:]

# %%
new4_2017
# Out:
#                                              Entity  \
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# 17                         Driving Standards Agency
# ...

# %%
new4_2017
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
new4_2017.to_excel("2017_clean_v2.0.xlsx")

# %%
new4_2017

# %%
new4_2017

# %% [markdown]
# https://public.tableau.com/profile/priyanka.n4310#!/vizhome/DataBreaches_2017update/Dashboard1?publish=yes
